# %%
#Medical Image Analysis with Deep Learning 

import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
obj_img=cv2.imread('E:\Images\sachin.jpg')
plt.imshow(obj_img)

plt.show()

# %%
obj_img=cv2.imread('E:\Images\sachin.jpg')
plt.imshow(obj_img)
plt.show()

# %%
#https://androidkt.com/tensorflow-image-augmentation-using-tf-image/
#https://pythonexamples.org/python-opencv-convert-image-to-black-and-white/

# %%
obj_img1=cv2.imread('E:\Images\Apple.jpg')
plt.imshow(obj_img1)
